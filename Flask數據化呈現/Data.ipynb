# %%
import pandas as pd
import os
# file = os.path.dirname(os.path.realpath(__file__))
data =pd.read_csv("./電動車拖吊資料.csv")
data
# Out:
#         報修日期     報修單號 派遣給司機時間 司機到達現場時間 司機拖吊完成時間   拖吊里程 車種(二輪/四輪)      廠牌  \
# 0      43466  7529415   00:58     2:19    02:48    4.0        四輪  TOYOTA
# 1      43466  7529443   02:22    02:50    03:06    5.0        二輪  GOGORO
# 2      43466  7529461   05:27    06:03    08:58   16.0        二輪  GOGORO
# 3      43466  7529476   07:31    09:00    11:33  155.0        四輪   LEXUS
# 4      43466  7529560   10:18    10:49    11:40   50.0        四輪   LEXUS
# ...      ...      ...     ...      ...      ...    ...       ...     ...
# 22185  44286  8149747   19:57    20:11    20:29    2.0        二輪  Gogoro
# 22186  44286  8149780   21:03    21:28    22:27    6.0        二輪  Gogoro
# 22187  44286  8149782   21:06    21:43    22:03    2.0        二輪  Gogoro
# 22188  44286  8149797   21:53    22:05    22:49    4.0        二輪  Gogoro
# 22189  44286  8149807   22:19    23:09    00:17    4.0        二輪  Gogoro
#
#                      車型   車輛故障縣市(起拖地)       車輛故障地址(起拖地)  目的縣市(放車地)  \
# ...

# %%
import re
arr = data['車輛故障原因'].value_counts()
print(arr)
i = []
for x in range( 0 ,len(arr)):
        y = re.sub('\s','',arr.keys()[x])
        if re.search('\s',arr.keys()[x])!=None:
            if arr[y] > 0 :
                arr[y] = arr[y]+arr[x]
                i.append(arr.keys()[x]) 
            else :
                arr[y] = 0+1
                i.append(arr.keys()[x]) 
arr.drop(i)
len(arr)
# Out:
# 505車禍            5787
# 201無法啟動          5513
# 202無法行駛          2607
# G04無法啟動          1744
# 205機械故障          1635
# 103後輪破胎          1255
# 102前輪破胎           817
# G05無法騎乘           692
# G01事故             606
# 204皮帶斷裂           231
# G08事故             215
# G12無法騎乘           125
# 601運送車            122
# G11無法啟動/儀表板全黑     112
# 210煞車失靈            99
# G20鑰匙鎖車廂           70
# G06龍頭無法解鎖          67
# 211溫度升高            56
# 208無法排擋            51
# 105車門反鎖            40
# G17龍頭無法解鎖          27
# 104缺油              24
# G26換電失敗            23
# 207油路有問題           21
# G02爆胎              21
# 203水箱破裂            21
# 106車胎沒氣            20
# 501陷入溝洞            19
# G13故障燈號/燈號異常       19
# G30車廂無法關閉          17
# G21鑰匙遺失            16
# 206電路有問題           15
# G09爆胎              14
# 301泡水車             13
# G23卡彈              13
# G24換電異常/無法換電       12
# 101電瓶沒電             7
# 303火燒車              6
# 503車底卡住             6
# G33後輪鎖死             4
# G02鑰匙鎖車廂            3
# ...

# %%
from flask import Flask

from pyecharts import options as opts
from pyecharts.charts import Bar
from random import randrange

app = Flask(__name__)

#########################以下代码可以替换！！！為設定值
def bar_base() -> Bar:
    c = (Bar()
        .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
        .add_yaxis("商家A", [randrange(0, 100) for _ in range(6)])
        .add_yaxis("商家B", [randrange(0, 100) for _ in range(6)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题")))
    
    return c
##########################################
@app.route("/")
def index():
    c = bar_base()
    return render_template('index.html')

@app.route("/barChart")
def get_bar_chart():
    c = bar_base()
    return c.dump_options_with_quotes()


if __name__ == "__main__":
    app.run(host='0.0.0.0' , port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.112:5000/ (Press CTRL+C to quit)
# 192.168.1.112 - - [14/Jun/2021 17:49:43] "GET / HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 17:49:43] "GET /static/js//echarts.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 17:49:43] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 17:49:43] "GET /barChart HTTP/1.1" 200 -

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"]) #x軸
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105]) 
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .add_yaxis("商家C", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)


# # 不习惯链式调用的开发者依旧可以单独调用方法
# bar = Bar()
# bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
# bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
# bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
# bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render() #會生成一個render.html檔案
bar.render_notebook() #在notebook裡呈現
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="11d2966039524999bd3d263ade18ee41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_11d2966039524999bd3d263ade18ee41 = echarts.init(
#                     document.getElementById('11d2966039524999bd3d263ade18ee41'), 'white', {renderer: 'canvas'});
#                 var option_11d2966039524999bd3d263ade18ee41 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#漏斗圖
from flask import Flask

from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

app = Flask(__name__)

#########################以下代码可以替换！！！為設定值
def Funnel_base():
    c = (Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例")))
    return c
##########################################
@app.route("/")
def index():
    c = Funnel_base()
    return render_template('index.html')

@app.route("/funnel_base")
def get_funnel_chart():
    c = Funnel_base()
    return c.dump_options_with_quotes()


if __name__ == "__main__":
    app.run(host='0.0.0.0' , port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.112:5000/ (Press CTRL+C to quit)
# 192.168.1.112 - - [14/Jun/2021 20:56:42] "GET / HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 20:56:42] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 20:56:42] "GET /static/js//echarts.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 20:56:42] "GET /funnel_base HTTP/1.1" 200 -

# %%
from flask import Flask

from pyecharts import options as opts
from pyecharts.charts import Bar
from random import randrange

app = Flask(__name__)

#########################以下代码可以替换！！！為設定值
def bar_base() -> Bar:
    c = (Bar()
        .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
        .add_yaxis("商家A", [randrange(0, 100) for _ in range(6)])
        .add_yaxis("商家B", [randrange(0, 100) for _ in range(6)])
        .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题")))
    
    return c
##########################################
@app.route("/")
def index():
    c = bar_base()
    return render_template('index.html')

@app.route("/barChart")
def get_bar_chart():
    c = bar_base()
    return c.dump_options_with_quotes()


if __name__ == "__main__":
    app.run(host='0.0.0.0' , port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.112:5000/ (Press CTRL+C to quit)
# 192.168.1.112 - - [14/Jun/2021 20:55:32] "GET / HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 20:55:32] "GET /static/js//echarts.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 20:55:32] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [14/Jun/2021 20:55:32] "GET /barChart HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 20:55:34] "GET /barChart HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 20:55:36] "GET /barChart HTTP/1.1" 200 -
# 192.168.1.112 - - [14/Jun/2021 20:55:38] "GET /barChart HTTP/1.1" 200 -
# ...

# %%
#折線圖
import random
from flask.json import jsonify
from flask import Flask, render_template

from pyecharts import options as opts
from pyecharts.charts import Line


app = Flask(__name__)


def line_base() -> Line:
    line = (
        Line()
        .add_xaxis(["{}".format(i) for i in range(10)])
        .add_yaxis(
            series_name="",
            y_axis=[randrange(50, 80) for _ in range(10)],
            is_smooth=True,
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="动态数据"),
            xaxis_opts=opts.AxisOpts(type_="value"),
            yaxis_opts=opts.AxisOpts(type_="value"),
        )
    )
    return line


@app.route("/")
def index():
    return render_template("index.html")


@app.route("/lineChart")
def get_line_chart():
    c = line_base()
    return c.dump_options_with_quotes()


idx = 9
a = [50,52]


@app.route("/lineDynamicData")
def update_line_data():
    global idx
    idx = idx + 0.5 #控制每次動態的見隔
    return jsonify({"name": idx, "value": a[random.randint(0,1)]}) #value是每次動態產生的值


if __name__ == "__main__":
    app.run(host='0.0.0.0' , port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.112:5000/ (Press CTRL+C to quit)
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET / HTTP/1.1" 200 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /static/js//echarts.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /lineChart HTTP/1.1" 200 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /lineDynamicData HTTP/1.1" 200 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /lineDynamicData HTTP/1.1" 200 -
# 192.168.1.112 - - [16/Jun/2021 00:04:14] "GET /lineDynamicData HTTP/1.1" 200 -
# ...

# %%
arr = data['車型'].value_counts()
vehicles = data['車種(二輪/四輪)'].value_counts()
list(vehicles.keys())
list(vehicles)
arr = data['車型'].value_counts()
arr_data=[]
x = 0
for i in dict(arr).keys() :
    ddata = {'value':int(dict(arr)[i]),'name':i }
    arr_data.append(ddata)
    
print(arr_data)
# Out:
# [{'value': 9100, 'name': 'GOGORO 2'}, {'value': 1973, 'name': 'GOGORO 1'}, {'value': 1641, 'name': 'GOGORO 3'}, {'value': 1104, 'name': 'CAMRY(油電)'}, {'value': 1015, 'name': 'Prius C (油電)'}, {'value': 1009, 'name': 'CT-200h(油電)'}, {'value': 733, 'name': 'PRIUS(油電)'}, {'value': 581, 'name': 'RX-450h(油電)'}, {'value': 551, 'name': 'GOGORO 4 (VIVA)'}, {'value': 498, 'name': 'ALTIS(油電)'}, {'value': 456, 'name': 'ES-300h(油電)'}, {'value': 432, 'name': 'Gogoro 2'}, {'value': 361, 'name': 'IS-300h(油電)'}, {'value': 307, 'name': 'NX-300h(油電)2WD'}, {'value': 140, 'name': 'Model 3(不可接電)'}, {'value': 136, 'name': 'GS-450h(油電)'}, {'value': 128, 'name': 'Ai-1 Sport'}, {'value': 117, 'name': 'Model X(不可接電)'}, {'value': 116, 'name': 'Model S(不可接電)'}, {'value': 102, 'name': 'Gogoro 3'}, {'value': 87, 'name': 'PRIUS Alpha(油電)'}, {'value': 86, 'name': 'NX-300h(油電)4WD'}, {'value': 76, 'name': 'Gogoro 1'}, {'value': 72, 'name': 'Gogoro VIVA'}, {'value': 72, 'name': 'RAV4(油電)'}, {'value': 72, 'name': 'GS-30
# ...

# %%
#標準矩陣圖
from flask import Flask , render_template

from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.charts import TreeMap
from random import randrange

app = Flask(__name__)

#########################以下代码可以替换！！！為設定值
def bar_base() -> Bar:
    c = (Bar()
        .add_xaxis(list(vehicles.keys()))
        .add_yaxis("",list(vehicles))
        .set_global_opts(title_opts=opts.TitleOpts(title="車種")))
    
    return c

def tree() -> Bar:
    c=(
    TreeMap()
    .add(
        series_name="DEMO",
        data=arr_data , 
        #levels 為每個層級分別設定
        levels=[opts.TreeMapLevelsOpts(treemap_itemstyle_opts=opts.TreeMapItemStyleOpts(border_color="#555",
        border_width=4, gap_width=4))],color_alpha=[0.3 , 0.4]
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="車型"))
#     .render("层级矩阵树图.html")
)
    return c

##########################################
@app.route("/")
def index():
    c = bar_base()
    return render_template('index.html')

@app.route("/barChart")
def get_bar_chart1():
    c = bar_base()
    return c.dump_options_with_quotes()

@app.route("/treecharts")
def get_tree_chart():
    c2 = tree()
    return c2.dump_options_with_quotes()


if __name__ == "__main__":
    app.run(host='0.0.0.0' , port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.112:5000/ (Press CTRL+C to quit)
# 192.168.1.112 - - [15/Jun/2021 23:37:35] "GET / HTTP/1.1" 200 -
# 192.168.1.112 - - [15/Jun/2021 23:37:35] "GET /static/js/jquery.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [15/Jun/2021 23:37:35] "GET /static/js//echarts.min.js HTTP/1.1" 304 -
# 192.168.1.112 - - [15/Jun/2021 23:37:35] "GET /barChart HTTP/1.1" 200 -
# 192.168.1.112 - - [15/Jun/2021 23:37:35] "GET /treecharts HTTP/1.1" 200 -

# %%
from pyecharts import options as opts
from pyecharts.charts import TreeMap
from pyecharts.globals import ThemeType

# data , item_opts=[],[]
# for item in arr_data:
#     data.append(opts.TreeItem(name=item['name'] , value=item['value'] , label_opts=opts.LabelOpts(color='white' , font_size=16 , position='inside')))
    
c = (
    TreeMap(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add("标准矩阵树图", 
         data = arr_data,
         levels=[opts.TreeMapLevelsOpts(treemap_itemstyle_opts=opts.TreeMapItemStyleOpts(border_color="white",
        border_width=1, gap_width=1))],color_alpha=[0.3 , 0.4]
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="标准矩阵树图",pos_left='left') , 
                     visualmap_opts=opts.VisualMapOpts(type_='color' , range_color=['rgba(0,0,252,0.1)', 'rgba(0,0,253,1)'] , min_=0,max_=5000
                                                      ,dimension=0))
#     .render("标准矩阵树图.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b986b7a88e954908b0a59c2f7b49e7e4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b986b7a88e954908b0a59c2f7b49e7e4 = echarts.init(
#                     document.getElementById('b986b7a88e954908b0a59c2f7b49e7e4'), 'dark', {renderer: 'canvas'});
#                 var option_b986b7a88e954908b0a59c2f7b49e7e4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6807\u51c6\u77e9\u9635\u6811\u56fe",
#             "data": [
# ...

# %%
import re
import pandas as pd

data =pd.read_csv("./電動車拖吊資料.csv")
for x,y in enumerate(data['車型']) :
    try:
        data['車型'][x]=re.sub('\(.+\)', '', data['車型'][x])
    except:
        pass
    try:
        data['廠牌'][x]=re.sub('\s', '', data['廠牌'][x])
    except:
        pass
    try:
        data['廠牌'][x]=re.sub('Gogoro', 'GOGORO', data['廠牌'][x])
    except:
        pass
# Out:
# <ipython-input-376-47b3473fa4bf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['車型'][x]=re.sub('\(.+\)', '', data['車型'][x])
# <ipython-input-376-47b3473fa4bf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['廠牌'][x]=re.sub('\s', '', data['廠牌'][x])
# <ipython-input-376-47b3473fa4bf>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['廠牌'][x]=re.sub('Gogoro', 'GOGORO', data['廠牌'][x])

# %%
data.head()
# Out:
#     報修日期     報修單號 派遣給司機時間 司機到達現場時間 司機拖吊完成時間   拖吊里程 車種(二輪/四輪)      廠牌  \
# 0  43466  7529415   00:58     2:19    02:48    4.0        四輪  TOYOTA
# 1  43466  7529443   02:22    02:50    03:06    5.0        二輪  GOGORO
# 2  43466  7529461   05:27    06:03    08:58   16.0        二輪  GOGORO
# 3  43466  7529476   07:31    09:00    11:33  155.0        四輪   LEXUS
# 4  43466  7529560   10:18    10:49    11:40   50.0        四輪   LEXUS
#
#          車型   車輛故障縣市(起拖地)       車輛故障地址(起拖地)  目的縣市(放車地)  \
# 0     CAMRY  104132台北市中山區      濱江街95號(濱江小隊)  105台北市松山區
# 1  GOGORO 2  330000桃園市桃園區  中正路50號(近統領百貨桃園店)  330桃園市桃園區
# 2  GOGORO 2  249009新北市八里區       中華路二段252號前面  247新北市蘆洲區
# 3   RX-450h  946015屏東縣恆春鎮          恆公路1111號  710台南市永康區
# 4   RX-400h  920020屏東縣潮州鎮           光復路135號  820高雄市岡山區
#
#               目的保廠或指定地址(放車地)    車輛故障原因
# 0  08810501北都撫遠廠(17:30之後需預約)     505車禍
# 1              0Z833003桃園藝文店   G12無法騎乘
# 2           0Z824701蘆洲三民服務中心  G20鑰匙鎖車廂
# 3         05371003LEXUS南都台南廠     505車禍
# ...

# %%
Srr_data =[]
data[data['車種(二輪/四輪)'].isin([data['車種(二輪/四輪)'].unique()[0]])]
for i in range(0 , len(data['車種(二輪/四輪)'].unique())-1):
    a =data[data['車種(二輪/四輪)'].isin([data['車種(二輪/四輪)'].unique()[i]])]
    b = []
    
    for q in range(0 , len(a['廠牌'].unique())):
        if a['廠牌'].unique()[q] == 'nan':
            continue
        c = a[a['廠牌'].isin([a['廠牌'].unique()[q]])]
        d = []
        
        for r in range(0 , len(c['車型'].unique())):
            if c['車型'].unique()[r] == 'nan':
                continue
            e = c[c['車型'].isin([c['車型'].unique()[r]])]
            f = []
            
            for t in range(0 ,len(e['車輛故障原因'].unique())):
                if e['車輛故障原因'].unique()[t] == 'nan':
                    continue
                g = e[e['車輛故障原因'].isin([e['車輛故障原因'].unique()[t]])]
                f.append(opts.SunburstItem(name = e['車輛故障原因'].unique()[t],value=int(g['車輛故障原因'].count())))           
            
            d.append(opts.SunburstItem(name = c['車型'].unique()[r],value=int(e['車型'].count()),children=f ))
        b.append(opts.SunburstItem(name = a['廠牌'].unique()[q],value=int(c['廠牌'].count()) , children=d ))
    Srr_data.append(opts.SunburstItem(name =data['車種(二輪/四輪)'].unique()[i] , value=int(a['車種(二輪/四輪)'].count()),children=b , ))
    
    
print(Srr_data)

#[opts.SunburstItem(name , value , children=[opts.SunburstItem(name,value,children=[opts.SunburstItem(name,value,children)])])]
# Out:
# [<pyecharts.options.charts_options.SunburstItem object at 0x7fc320183f80>, <pyecharts.options.charts_options.SunburstItem object at 0x7fc3038a06c0>]

# %%
from pyecharts.charts import Sunburst
from pyecharts import options as opts
# data = [opts.SunburstItem(name="Grandpa",children=[opts.SunburstItem(name="Uncle Leo",value=15,children=[
#     opts.SunburstItem(name="Cousin Jack", value=2),opts.SunburstItem(name="Cousin Mary",value=5,
#     children=[opts.SunburstItem(name="Jackson", value=2)],),opts.SunburstItem(name="Cousin Ben", value=4),],),
#     opts.SunburstItem(name="Father",value=10,children=[opts.SunburstItem(name="Me", value=5),
#     opts.SunburstItem(name="Brother Peter", value=1),],),],),
#     opts.SunburstItem(name="Nancy",children=[opts.SunburstItem(name="Uncle Nike",children=[
#     opts.SunburstItem(name="Cousin Betty", value=1),opts.SunburstItem(name="Cousin Jenny", value=2),],
#     )],),]

c = (
    Sunburst(init_opts=opts.InitOpts(width="1000px", height="600px"))
    .add(series_name="", data_pair=Srr_data, radius=['10%', "90%"],highlight_policy='ancestor')
    .set_global_opts(title_opts=opts.TitleOpts(title="Sunburst-基本示例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="57a211ec4d4540d78bbd81f6bb8f3300" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_57a211ec4d4540d78bbd81f6bb8f3300 = echarts.init(
#                     document.getElementById('57a211ec4d4540d78bbd81f6bb8f3300'), 'white', {renderer: 'canvas'});
#                 var option_57a211ec4d4540d78bbd81f6bb8f3300 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
